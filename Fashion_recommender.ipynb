# %%
 pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow
from keras.applications.resnet50 import ResNet50, preprocess_input
from keras.layers import GlobalMaxPooling2D

# %%
model=ResNet50(weights='imagenet',include_top=False, input_shape=(224,224,3))
model.trainable=False

# %%
model=tensorflow.keras.Sequential([
    model, 
    GlobalMaxPooling2D()
])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)                │ (None, 7, 7, 2048)          │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_max_pooling2d                 │ (None, 2048)                │               0 │
# │ (GlobalMaxPooling2D)                 │                             │                 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 23,587,712 (89.98 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    - -------------------------------------- 1.8/39.5 MB 11.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.2/39.5 MB 11.5 MB/s eta 0:00:04
#    ------ --------------------------------- 6.6/39.5 MB 10.9 MB/s eta 0:00:04
#    --------- ------------------------------ 8.9/39.5 MB 11.3 MB/s eta 0:00:03
#    ----------- ---------------------------- 11.3/39.5 MB 11.0 MB/s eta 0:00:03
#    ------------- -------------------------- 13.6/39.5 MB 11.1 MB/s eta 0:00:03
#    --------------- ------------------------ 15.5/39.5 MB 10.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 17.3/39.5 MB 10.8 MB/s eta 0:00:03
#    ------------------- -------------------- 19.4/39.5 MB 10.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 21.8/39.5 MB 10.5 MB/s eta 0:00:02
# ...

# %%
import cv2
import numpy as np
from numpy.linalg import norm

# %%
import os
import cv2

dataset_path = r"C:\Users\Lenovo\Desktop\FASHION RECOMMENDER\Dataset"  # Use raw string

if not os.path.exists(dataset_path):
    print("❌ Path does not exist:", dataset_path)
else:
    print("✅ Path exists")
    image_files = os.listdir(dataset_path)
    print("Found files:", image_files[:5])  # Preview first 5 files

    for file in image_files:
        file_path = os.path.join(dataset_path, file)
        img = cv2.imread(file_path)

        if img is not None:
            img = cv2.resize(img, (224, 224))
            print(f"✅ Loaded and resized: {file}")
        else:
            print(f"❌ Failed to load: {file}")
# Out:
# ✅ Path exists
# Found files: ['10037.jpg', '10039.jpg', '10054.jpg', '10096.jpg', '10097.jpg']
# ✅ Loaded and resized: 10037.jpg
# ✅ Loaded and resized: 10039.jpg
# ✅ Loaded and resized: 10054.jpg
# ✅ Loaded and resized: 10096.jpg
# ✅ Loaded and resized: 10097.jpg
# ✅ Loaded and resized: 10110.jpg
# ✅ Loaded and resized: 10174.jpg
# ✅ Loaded and resized: 10180.jpg
# ✅ Loaded and resized: 10266.jpg
# ✅ Loaded and resized: 10267.jpg
# ✅ Loaded and resized: 10268.jpg
# ✅ Loaded and resized: 10269.jpg
# ✅ Loaded and resized: 10292.jpg
# ✅ Loaded and resized: 10293.jpg
# ✅ Loaded and resized: 10294.jpg
# ✅ Loaded and resized: 10295.jpg
# ✅ Loaded and resized: 10307.jpg
# ✅ Loaded and resized: 10309.jpg
# ✅ Loaded and resized: 10632.jpg
# ✅ Loaded and resized: 10633.jpg
# ✅ Loaded and resized: 10634.jpg
# ✅ Loaded and resized: 10635.jpg
# ✅ Loaded and resized: 10649.jpg
# ✅ Loaded and resized: 10671.jpg
# ✅ Loaded and resized: 10672.jpg
# ✅ Loaded and resized: 10755.jpg
# ...

# %%
# Out:
# ['.ipynb_checkpoints', 'Dataset', 'Fashion_recommender.ipynb']
